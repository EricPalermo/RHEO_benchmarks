# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
from scipy.stats import linregress
import os
from netCDF4 import Dataset
import matplotlib.ticker as mticker

#For plotting binned velocity profile
from scipy.stats import binned_statistic as bstats

# %%
# Import and apply style file for plots
plt.style.use("mpl.style")

# %% [markdown]
# # Functions
# For any 2D or 3D Taylor-Vortex, calculate and compare LAMMPS kinetic energy and viscosity data to the analytical solution

# %% [markdown]
# ## New Code

# %%
#Compile all filenames (value) and properties (key) into a dictionary
def generate_file_names(filepath):
    data_files = {}

    for file in os.listdir(filepath):

        #Remove the .nc extension
        #Collect the info for the run in an array
        file_info = file.split(".")
        file_info = file_info[0].split("_")

        #File name
        file_name = file

        #Add the files to datafiles dictionary
        data_files[(file_info[0],file_info[1],file_info[2])]= filepath + "/" + file_name
    return data_files

# %%
#Return the normalized Kinetic energy (KE/KE_0) as a function of time
def analyt_KE(t):
    KE_norm = np.exp(-16*np.pi**2*nu*t)
    return KE_norm1

#Retrun the normalized Kinetic energy for a dataset
def data_KE(ds,scaling_vars):
    mp = scaling_vars[1]
    
    td = ds["time"][:]
    xd = ds['coordinates'][:,:,0] #At timestep nf, for all particles, x position
    yd = ds["coordinates"][:,:,1] #At timestep nf, for all particles, y position
    vxd = ds["velocities"][:,:,0] #At timestep nf, for all particles, x position
    vyd = ds['velocities'][:,:,1] #At timestep nf, for all particles, y velocity
    Exd = 0.5*mp*(np.sum(np.abs(vxd), axis=1))**2
    Eyd = 0.5*mp*(np.sum(np.abs(vyd), axis=1))**2
    E_tot = Exd+Eyd
    return [td,E_tot/E_tot[0]]

# %%
def compile_run_data(data_files):
    
    all_run_data = {}

    for run in data_files:
        #Parse file name for run parameters
        run_info = list(run)
        var_0 = var_0_key[run_info[0]] #Shifting
        var_1 = var_1_key[run_info[1]] #CRK or Quintic
        #Load the netcdf datafile from the file name
        ds = Dataset(data_files[run])
        
        #Calculate run-specific scaling variables
        sf = 1/int(run_info[2]) #Scaling of unit cell
        L_z = h3*(d-2)*sf #Account for L_z if d=3
        n = 1/sf**d #Number density - number of particles per volume
        mp = rho/n #Mass of particles (density is constant)
        
        #Calculate total number of particles based on dimensionality (sq lattice)
        if d == 3:
            N = L_x*L_y*L_z/sf**d # Total number of atoms
        elif d == 2:
            N = L_x*L_y/sf**d
        #Store run-specific variables for use in other calculations
        scaling_vars = [n,mp,N]
            
        all_run_data[(var_0,var_1,sf)] = [data_KE(ds,scaling_vars),scaling_vars]
    
    return all_run_data

# %%
#Input is the output of compile_run_data: dictionary of all run info and data
#Calculate values needed to plot viscosity error
def calc_viscosity_error(all_run_data):
    column_names = ["Shifting","RK","sf","Viscosity Normalized L1"]
    df = pd.DataFrame(columns=column_names)
    #df.sort_values(by=["sf","var1"], inplace=True)
    for count,run in enumerate(all_run_data):
        KE_data = all_run_data[run][0]
        slope_data = linregress(KE_data[0],np.log(KE_data[1]))[0]
        nu_data = -slope_data/(2*(k_x**2+k_y**2))
        N = all_run_data[run][1][2]
        nu_error_norm =  np.abs(nu_data-nu)/N
        for i in len(run)
        run_data_w_nu = run_data.append(nu_error_norm)
        print(run_data_w_nu)
        #run_df = pd.DataFrame(run_data, columns = column_names)
        #df.append(run_df)
             
    return df
# Out:
#   File "/tmp/ipykernel_10449/844436946.py", line 13
#     for i in len(run)
#                      ^
# SyntaxError: invalid syntax

# %% [markdown]
# Test if the code is working

# %%
###Keys for stylizing the plot###
var_0_key = {"0":"Shifting Off","1":"Shifting On"} #Viscosity calc method
var_1_key = {"5":"Quintic","0":"CRK0", "1":"CRK1", "2":"CRK2"}
plot_key = {"Quintic":["o","darkgreen"],"CRK0":["X","lightblue"], "CRK1":["s","blue"],"CRK2":["d","darkblue"]}

###System Properties###
#System dimensions
d = 2
#Smoothing length coefficient
h3 = 3.5
#System size
L_x = 10 #Size of the system
L_y = L_x
#Fluid properties
eta = 0.1
rho = 1
nu = eta/rho
#Oscillation properties
u_0 = 0.1
k_x = 2*np.pi/L_x
k_y = 2*np.pi/L_y
#Decay timescale
tau = 1/nu/(k_x**2+k_y**2)



###Data Files###
filepath = '/home/epalermo/dev/test/taylor_green_vortex/taylor_green_2D/current_data_files'
filenames = generate_file_names(filepath)
run_data = compile_run_data(filenames)
df = calc_viscosity_error(run_data)
df
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# Empty DataFrame
# Columns: [Shifting, RK, sf, Viscosity Normalized L1]
# Index: []

# %% [markdown]
# ## Old Code Below

# %%
#Benchmark by plotting kinetic energy decay and viscosity
def benchmark(data_files):
    
    fig, ax = plt.subplots(2,1,figsize=(10,15))

        #Calculate kinetic energy decay and plot it
        td, E_tot, ref_E_tot = data_KE(ds, mp, N)
        if sf == 0.1: #Only plot sf=0.1 runs
            ax[0].semilogy(td*u_0/L_x, E_tot/E_tot[0],
                           marker=plot_key[run_info[1]][0],
                           markevery=20,
                           markerfacecolor="None",
                           color=plot_key[run_info[1]][1],
                           label = run_info[1])

        #Calculate viscosity error
        nu_L1_norm = calc_viscosity_error(td, E_tot, ref_E_tot)/N
        run_info.append(nu_L1_norm)
        
        all_run_info.append(run_info)
    
    #Plot KE decay from analytical velocity profile
    ax[0].semilogy(td*u_0/L_x, ref_E_tot/ref_E_tot[0],
                   label = "Analytic",
                   color="red",
                   linestyle=":",
                   linewidth=4)
    
    #Format kinetic energy decay plot
    ax[0].set_ylabel(r"$\log{(\frac{E_k}{E_{k0}})}$")
    ax[0].set_xlabel(r"$\frac{tu_0}{L}$")
    ax[0].set_xlim(0,1)
    ax[0].set_ylim(1e-5,1)
    handles,labels = ax[0].get_legend_handles_labels()

    handles = [handles[3], handles[0], handles[2], handles[1], handles[4]]
    labels = [labels[3], labels[0], labels[2], labels[1], labels[4]]
    ax[0].legend(handles,labels,loc="lower left")
    
    #Plot viscosity error
    df = pd.DataFrame(all_run_info, columns=["var0","var1","sf","Viscosity Normalized L1"])
    df.sort_values(by=["sf","var1"], inplace=True)
    
    for i in df["var0"].unique():
        df_1 = df[df["var0"]==i]
        for j in df_1["var1"].unique():
            df_2 = df_1[df_1["var1"]==j]
            label = j
            ax[1].loglog(L_x/df_2["sf"],df_2["Viscosity Normalized L1"],
                         marker=plot_key[j][0],
                         markerfacecolor="None",
                         color=plot_key[j][1],
                         label=label)
            nu_error_slope = np.log(L_x/df_2["sf"]).corr(np.log(df_2["Viscosity Normalized L1"]))
            print("Slope " + "(" + label + ")" + " : " + str(nu_error_slope))
            print(df_2)

    #Format viscosity error plot
    ax[1].legend(loc="lower left")
    ax[1].set_ylabel(r"$\log{(\frac{L_1}{N})}$")
    ax[1].set_xlabel(r"$\log{(\frac{L}{\Delta x})}$")
    ax[1].set_xlim(10**0.9,10**2.5)

    
    plt.tight_layout()

# %%
#Calculate velocity from analytical solution to Taylor-Green Vortex
def vel_x_y_t(x,y,t,k_x,k_y,tau):
    u_x = -u_0*np.cos(k_x*x)*np.sin(k_y*y)
    u_y = u_0*np.sin(k_x*x)*np.cos(k_y*y)
    u_t = np.exp(-t/tau)
    return np.sum(np.abs(u_x), axis=1)*u_t , np.sum(np.abs(u_y), axis=1)*u_t

# %% [markdown]
# # Test Cases

# %% [markdown]
# ## 2D Taylor Green Vortex
# * Variables:
#     * var_0 = no-shifting/shifting
#     * var_1 = quintic/RK

# %%
###Keys for stylizing the plot###
var_0_key = {"0":"Shifting Off","1":"Shifting On"} #Viscosity calc method
var_1_key = {"5":"Quintic","0":"CRK0", "1":"CRK1", "2":"CRK2"}
plot_key = {"Quintic":["o","darkgreen"],"CRK0":["X","lightblue"], "CRK1":["s","blue"],"CRK2":["d","darkblue"]}

###System Properties###
#System dimensions
d = 2
#Smoothing length coefficient
h3 = 3.5
#System size
L_x = 10 #Size of the system
L_y = L_x
#Fluid properties
eta = 0.1
rho = 1
nu = eta/rho
#Oscillation properties
u_0 = 0.1
k_x = 2*np.pi/L_x
k_y = 2*np.pi/L_y
#Decay timescale
tau = 1/nu/(k_x**2+k_y**2)



###Data Files###
filepath = '/home/epalermo/dev/test/taylor_green_vortex/taylor_green_2D/current_data_files'
benchmark(generate_file_names(filepath))
# Out:
# Slope (CRK0) : -0.9424834675666229
#            var0  var1    sf  Viscosity Normalized L1
# 16  Shifting On  CRK0  0.05             6.180345e-07
# 17  Shifting On  CRK0  0.10             4.435946e-07
# 11  Shifting On  CRK0  0.20             2.016397e-05
# 0   Shifting On  CRK0  0.25             3.288254e-05
# 10  Shifting On  CRK0  0.50             1.731550e-04
# Slope (CRK1) : -0.9606320203446425
#            var0  var1    sf  Viscosity Normalized L1
# 13  Shifting On  CRK1  0.05                 0.000002
# 2   Shifting On  CRK1  0.10                 0.000009
# 8   Shifting On  CRK1  0.20                 0.000032
# 9   Shifting On  CRK1  0.25                 0.000018
# 18  Shifting On  CRK1  0.50                 0.000072
# Slope (CRK2) : -0.9751499972422507
#            var0  var1    sf  Viscosity Normalized L1
# 15  Shifting On  CRK2  0.05             3.339911e-07
# 12  Shifting On  CRK2  0.10             5.144522e-07
# 6   Shifting On  CRK2  0.25             1.793400e-05
# 7   Shifting On  CRK2  0.50             1.523009e-04
# Slope (Quintic) : -0.9997801963612675
#            var0     var1    sf  Viscosity Normalized L1
# 14  Shifting On  Quintic  0.05             6.605031e-07
# 3   Shifting On  Quintic  0.10             3.911192e-06
# 1   Shifting On  Quintic  0.20             2.016397e-05
# 5   Shifting On  Quintic  0.25             3.288254e-05
# 4   Shifting On  Quintic  0.50             1.731550e-04

# %% [markdown]
# ## 3D Taylor Green Vortex
# * 3D system with no initial velocity in the z direction
# * Variables:
#     * var_0 = no-shifting/shifting
#     * var_1 = quintic/RK

# %%
###Keys for stylizing the plot###
var_0_key = {"0":["Shifting Off","blue"],"1":["Shifting On","green"]} #Viscosity calc method
var_1_key = {"5":["Quintic","."],"0":["CRK0","-."], "1":["CRK1","-"], "2":["CRK2","--"]}
kernel_marker_key = {"Quintic":".","CRK0""-.", "1":["CRK1","-"], "2":["CRK2","--"]}
#sf_key = {0.05:"-",0.1:"--",0.2:"-.",0.25:":",0.5:(0,(5,10))}


###System Properties###
#System dimensions
d = 3
#Smoothing length coefficient
h3 = 3.5
#System size
L_x = 10 #Size of the system
L_y = L_x
#Fluid properties
eta = 0.01
rho = 1
nu = eta/rho
#Oscillation properties
u_0 = 0.1
k_x = 2*np.pi/L_x
k_y = 2*np.pi/L_y
#Decay timescale
tau = 1/nu/(k_x**2+k_y**2)

###Data Files###
filepath = '/home/epalermo/dev/test/taylor_green_vortex/taylor_green_3D/data_files/variable_timestep'
benchmark(generate_file_names(filepath))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/src/anaconda3/lib/python3.9/site-packages/matplotlib/markers.py in _set_marker(self, marker)
#     326             try:
# --> 327                 Path(marker)
#     328                 self._marker_function = self._set_vertices
#
# ~/src/anaconda3/lib/python3.9/site-packages/matplotlib/path.py in __init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     127         """
# --> 128         vertices = _to_unmasked_float_array(vertices)
#     129         _api.check_shape((None, 2), vertices=vertices)
#
# ~/src/anaconda3/lib/python3.9/site-packages/matplotlib/cbook/__init__.py in _to_unmasked_float_array(x)
#    1332     else:
# -> 1333         return np.asarray(x, float)
#    1334
#
# ValueError: could not convert string to float: '-'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4840/18389539.py in <module>
#      27 ###Data Files###
#      28 filepath = '/home/epalermo/dev/test/taylor_green_vortex/taylor_green_3D/data_files/variable_timestep'
# ---> 29 benchmark(generate_file_names(filepath))
#
# /tmp/ipykernel_4840/2530584147.py in benchmark(data_files)
#      30         td, E_tot, ref_E_tot = calc_kinetic_energy_decay(ds, mp, N)
#      31         if sf == 0.1:
# ---> 32             ax[0].semilogy(td*u_0/L_x, E_tot/E_tot[0],
#      33                            marker=var_1_key[var_1][1],
#      34                            markevery=20,
#
# ~/src/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py in semilogy(self, *args, **kwargs)
#    1827                       'basey', 'subsy', 'nonposy']}
#    1828         self.set_yscale('log', **d)
# -> 1829         return self.plot(
#    1830             *args, **{k: v for k, v in kwargs.items() if k not in d})
#    1831
#
# ~/src/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
#    1604         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1605         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1606         for line in lines:
#    1607             self.add_line(line)
#
# ~/src/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     313                 this += args[0],
#     314                 args = args[1:]
# --> 315             yield from self._plot_args(this, kwargs)
#     316
#     317     def get_next_color(self):
#
# ~/src/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     537             return list(result)
#     538         else:
# --> 539             return [l[0] for l in result]
#     540
#     541
#
# ~/src/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in <listcomp>(.0)
#     537             return list(result)
#     538         else:
# --> 539             return [l[0] for l in result]
#     540
#     541
#
# ~/src/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in <genexpr>(.0)
#     530             labels = [label] * n_datasets
#     531
# --> 532         result = (make_artist(x[:, j % ncx], y[:, j % ncy], kw,
#     533                               {**kwargs, 'label': label})
#     534                   for j, label in enumerate(labels))
#
# ~/src/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in _makeline(self, x, y, kw, kwargs)
#     352         default_dict = self._getdefaults(set(), kw)
#     353         self._setdefaults(default_dict, kw)
# --> 354         seg = mlines.Line2D(x, y, **kw)
#     355         return seg, kw
#     356
#
# ~/src/anaconda3/lib/python3.9/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     373         self._color = None
#     374         self.set_color(color)
# --> 375         self._marker = MarkerStyle(marker, fillstyle)
#     376
#     377         self._markevery = None
#
# ~/src/anaconda3/lib/python3.9/site-packages/matplotlib/markers.py in __init__(self, marker, fillstyle)
#     234         self._marker_function = None
#     235         self._set_fillstyle(fillstyle)
# --> 236         self._set_marker(marker)
#     237
#     238     def _recache(self):
#
# ~/src/anaconda3/lib/python3.9/site-packages/matplotlib/markers.py in _set_marker(self, marker)
#     328                 self._marker_function = self._set_vertices
#     329             except ValueError as err:
# --> 330                 raise ValueError('Unrecognized marker style {!r}'
#     331                                  .format(marker)) from err
#     332
#
# ValueError: Unrecognized marker style '-'

# %% [markdown]
# ## Visocsity Calculation Method
#
# * Based on 2D Taylor-Green system
# * Shifting and RK always on
# * Varies the method that RHEO uses to calculate the viscosity

# %%
###Keys for stylizing the plot###
var_0_key = {"0":["grad-grad form","blue"],"1":["King 2021 form","green"]} #Viscosity calc method
var_1_key = {"5":["Quintic","-."],"0":["CRK0","-."], "1":["CRK1","-"], "2":["CRK2","--"]}
#sf_key = {0.05:"-",0.1:"--",0.2:"-.",0.25:":",0.5:(0,(5,10))}


###System Properties###
#System dimensions
d = 3
#Smoothing length coefficient
h3 = 3.5
#System size
L_x = 10 #Size of the system
L_y = L_x
#Fluid properties
eta = 0.01
rho = 1
nu = eta/rho
#Oscillation properties
u_0 = 0.1
k_x = 2*np.pi/L_x
k_y = 2*np.pi/L_y
#Decay timescale
tau = 1/nu/(k_x**2+k_y**2)

###Data Files###
filepath = '/home/epalermo/dev/test/viscosity_test/data_files'
benchmark(generate_file_names(filepath))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/src/anaconda3/lib/python3.9/site-packages/matplotlib/markers.py in _set_marker(self, marker)
#     326             try:
# --> 327                 Path(marker)
#     328                 self._marker_function = self._set_vertices
#
# ~/src/anaconda3/lib/python3.9/site-packages/matplotlib/path.py in __init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     127         """
# --> 128         vertices = _to_unmasked_float_array(vertices)
#     129         _api.check_shape((None, 2), vertices=vertices)
#
# ~/src/anaconda3/lib/python3.9/site-packages/matplotlib/cbook/__init__.py in _to_unmasked_float_array(x)
#    1332     else:
# -> 1333         return np.asarray(x, float)
#    1334
#
# ValueError: could not convert string to float: '-.'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4840/3250676039.py in <module>
#      26 ###Data Files###
#      27 filepath = '/home/epalermo/dev/test/viscosity_test/data_files'
# ---> 28 benchmark(generate_file_names(filepath))
#
# /tmp/ipykernel_4840/2550003411.py in benchmark(data_files)
#      30         td, E_tot, ref_E_tot = calc_kinetic_energy_decay(ds, mp, N)
#      31         if sf == 0.1:
# ---> 32             ax[0].semilogy(td*u_0/L_x, E_tot/E_tot[0],
#      33                            marker=var_1_key[var_1][1],
#      34                            markevery=20,
#
# ~/src/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py in semilogy(self, *args, **kwargs)
#    1827                       'basey', 'subsy', 'nonposy']}
#    1828         self.set_yscale('log', **d)
# -> 1829         return self.plot(
#    1830             *args, **{k: v for k, v in kwargs.items() if k not in d})
#    1831
#
# ~/src/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
#    1604         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1605         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1606         for line in lines:
#    1607             self.add_line(line)
#
# ~/src/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     313                 this += args[0],
#     314                 args = args[1:]
# --> 315             yield from self._plot_args(this, kwargs)
#     316
#     317     def get_next_color(self):
#
# ~/src/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     537             return list(result)
#     538         else:
# --> 539             return [l[0] for l in result]
#     540
#     541
#
# ~/src/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in <listcomp>(.0)
#     537             return list(result)
#     538         else:
# --> 539             return [l[0] for l in result]
#     540
#     541
#
# ~/src/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in <genexpr>(.0)
#     530             labels = [label] * n_datasets
#     531
# --> 532         result = (make_artist(x[:, j % ncx], y[:, j % ncy], kw,
#     533                               {**kwargs, 'label': label})
#     534                   for j, label in enumerate(labels))
#
# ~/src/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in _makeline(self, x, y, kw, kwargs)
#     352         default_dict = self._getdefaults(set(), kw)
#     353         self._setdefaults(default_dict, kw)
# --> 354         seg = mlines.Line2D(x, y, **kw)
#     355         return seg, kw
#     356
#
# ~/src/anaconda3/lib/python3.9/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     373         self._color = None
#     374         self.set_color(color)
# --> 375         self._marker = MarkerStyle(marker, fillstyle)
#     376
#     377         self._markevery = None
#
# ~/src/anaconda3/lib/python3.9/site-packages/matplotlib/markers.py in __init__(self, marker, fillstyle)
#     234         self._marker_function = None
#     235         self._set_fillstyle(fillstyle)
# --> 236         self._set_marker(marker)
#     237
#     238     def _recache(self):
#
# ~/src/anaconda3/lib/python3.9/site-packages/matplotlib/markers.py in _set_marker(self, marker)
#     328                 self._marker_function = self._set_vertices
#     329             except ValueError as err:
# --> 330                 raise ValueError('Unrecognized marker style {!r}'
#     331                                  .format(marker)) from err
#     332
#
# ValueError: Unrecognized marker style '-.'

# %%
a_dict = {'color': 'blue', 'fruit': 'apple', 'pet': 'dog'}

# %%
list(a_dict)
# Out:
# ['color', 'fruit', 'pet']
